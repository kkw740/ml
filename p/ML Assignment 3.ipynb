# %%
import pandas as pd
data = pd.read_csv(r"C:\Users\HP\OneDrive\Desktop\ML\Assignment 3\temperatures.csv")
data
# Out:
#      YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP  \
# 0    1901  22.40  24.14  29.07  31.91  33.41  33.18  31.21  30.39  30.47
# 1    1902  24.93  26.58  29.77  31.78  33.73  32.91  30.92  30.73  29.80
# 2    1903  23.44  25.03  27.83  31.39  32.91  33.00  31.34  29.98  29.85
# 3    1904  22.50  24.73  28.21  32.02  32.64  32.07  30.36  30.09  30.04
# 4    1905  22.00  22.83  26.68  30.01  33.32  33.25  31.44  30.68  30.12
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 112  2013  24.56  26.59  30.62  32.66  34.46  32.44  31.07  30.76  31.04
# 113  2014  23.83  25.97  28.95  32.74  33.77  34.15  31.85  31.32  30.68
# 114  2015  24.58  26.89  29.07  31.87  34.09  32.48  31.88  31.52  31.55
# 115  2016  26.94  29.72  32.62  35.38  35.72  34.03  31.64  31.79  31.66
# 116  2017  26.45  29.46  31.60  34.95  35.84  33.82  31.88  31.72  32.22
#
#        OCT    NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# ...

# %%
print(data.columns)
# Out:
# Index(['YEAR', 'JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP',
#        'OCT', 'NOV', 'DEC', 'ANNUAL', 'JAN-FEB', 'MAR-MAY', 'JUN-SEP',
#        'OCT-DEC'],
#       dtype='object')

# %%
print("First Few Rows :")
print(data.head())
# Out:
# First Few Rows :
#    YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP    OCT  \
# 0  1901  22.40  24.14  29.07  31.91  33.41  33.18  31.21  30.39  30.47  29.97
# 1  1902  24.93  26.58  29.77  31.78  33.73  32.91  30.92  30.73  29.80  29.12
# 2  1903  23.44  25.03  27.83  31.39  32.91  33.00  31.34  29.98  29.85  29.04
# 3  1904  22.50  24.73  28.21  32.02  32.64  32.07  30.36  30.09  30.04  29.20
# 4  1905  22.00  22.83  26.68  30.01  33.32  33.25  31.44  30.68  30.12  30.67
#
#      NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# 0  27.31  24.49   28.96    23.27    31.46    31.27    27.25
# 1  26.31  24.04   29.22    25.75    31.76    31.09    26.49
# 2  26.08  23.65   28.47    24.24    30.71    30.92    26.26
# 3  26.36  23.63   28.49    23.62    30.95    30.66    26.40
# 4  27.52  23.82   28.30    22.25    30.00    31.33    26.57

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
sns.heatmap(data.corr(),annot=True)
plt.show()

# %%
sns.boxplot(data['ANNUAL'])
plt.show()

# %%
data_annual_avg = data[data['ANNUAL'] <= 30.5]
print(data_annual_avg)
print(data_annual_avg.shape)
# Out:
#      YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP  \
# 0    1901  22.40  24.14  29.07  31.91  33.41  33.18  31.21  30.39  30.47
# 1    1902  24.93  26.58  29.77  31.78  33.73  32.91  30.92  30.73  29.80
# 2    1903  23.44  25.03  27.83  31.39  32.91  33.00  31.34  29.98  29.85
# 3    1904  22.50  24.73  28.21  32.02  32.64  32.07  30.36  30.09  30.04
# 4    1905  22.00  22.83  26.68  30.01  33.32  33.25  31.44  30.68  30.12
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 110  2011  24.18  26.47  30.17  31.70  34.33  33.02  31.41  30.92  30.81
# 111  2012  23.61  26.44  30.20  32.46  34.30  33.60  31.88  30.96  30.65
# 112  2013  24.56  26.59  30.62  32.66  34.46  32.44  31.07  30.76  31.04
# 113  2014  23.83  25.97  28.95  32.74  33.77  34.15  31.85  31.32  30.68
# 114  2015  24.58  26.89  29.07  31.87  34.09  32.48  31.88  31.52  31.55
#
#        OCT    NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# ...

# %%
X = data.iloc[:,1:13]
Y = data['ANNUAL']
print(X.shape)
print(Y.shape)
# Out:
# (117, 12)
# (117,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size = 0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred = model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
mse = mean_squared_error(y_test,pred)
mae = mean_absolute_error(y_test,pred)
r2 = r2_score(y_test,pred)
print(f"Mean Squared Error(MSE) :{mse}")
print(f"Mean Absolute Error(MSE) :{mae}")
print(f"R2 Score:{r2}")
# Out:
# Mean Squared Error(MSE) :0.002440835094691429
# Mean Absolute Error(MSE) :0.02959015862325239
# R2 Score:0.9949515631120864

# %%
for i in range(1,13):
    print(data.columns[i])
    print(pred)
    print(f"Mean Squared Error(MSE) :{mse}")
# Out:
# JAN
# [28.93096171 28.49927279 28.86770544 28.7982968  28.60379388 29.32998297
#  29.39350215 30.18801006 28.67526783 28.94048822 29.48486967 28.60880511
#  29.65183247 29.60804475 28.62260919 28.96966894 29.02961241 29.79288206
#  29.41329518 30.27087614 29.6107913  29.16602639 31.64956747 28.69420619]
# Mean Squared Error(MSE) :0.002440835094691429
# FEB
# [28.93096171 28.49927279 28.86770544 28.7982968  28.60379388 29.32998297
#  29.39350215 30.18801006 28.67526783 28.94048822 29.48486967 28.60880511
#  29.65183247 29.60804475 28.62260919 28.96966894 29.02961241 29.79288206
#  29.41329518 30.27087614 29.6107913  29.16602639 31.64956747 28.69420619]
# Mean Squared Error(MSE) :0.002440835094691429
# MAR
# [28.93096171 28.49927279 28.86770544 28.7982968  28.60379388 29.32998297
#  29.39350215 30.18801006 28.67526783 28.94048822 29.48486967 28.60880511
#  29.65183247 29.60804475 28.62260919 28.96966894 29.02961241 29.79288206
# ...

# %%
plt.figure(figsize=(8,6))
plt.scatter(y_test,pred,color='red',label='Predicted vs Annual')
plt.plot([min(y_test),max(y_test)],[min(pred),max(pred)],color='blue')
plt.title('Actual vs Predicted Annual Temperature')
plt.xlabel('Actual Annual Temperature')
plt.ylabel('Predicted Annual Temperature')
plt.legend()
plt.show()
